# %% [markdown]
# # Assignment 6:  Due Thursday 10/12
#
# In this assignment you will become familiar with the Pandas library through the exploration of a Nobel prize data set.
#
# This data set was taken from the Kaggle website (https://www.kaggle.com/). If you are interested in data science and / or analysis, this website offers tons of data sets in various formats that you can access. They even post compititions that you can enter, some with money prizes awarded.
#
# The libraries needed for this assignment are listed below.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %% [markdown]
# # 1a)
#
# Read in the data set 'data/nobel.csv' into a DataFrame using Pandas .

# %%
dataset = pd.read_csv('data/nobel.csv')
df = pd.DataFrame(dataset)

# %% [markdown]
# # 1b)
#
# Display below the output from the DataFrame functions *info*.

# %%
df.info
# Out:
# <bound method DataFrame.info of      year    category                                           prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 906  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 907  2016       Peace                      The Nobel Peace Prize 2016
# 908  2016     Physics                 The Nobel Prize in Physics 2016
# 909  2016     Physics                 The Nobel Prize in Physics 2016
# 910  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# 0    "in recognition of the extraordinary services ...         1/1
# 1    "in special recognition of his poetic composit...         1/1
# 2    "for his work on serum therapy, especially its...         1/1
# 3                                                  NaN         1/2
# 4                                                  NaN         1/2
# ..                                                 ...         ...
# 906  "for his discoveries of mechanisms for autophagy"         1/1
# 907  "for his resolute efforts to bring the country...         1/1
# 908  "for theoretical discoveries of topological ph...         1/2
# 909  "for theoretical discoveries of topological ph...         1/4
# 910  "for theoretical discoveries of topological ph...         1/4
#
#      laureate_id laureate_type                     full_name  birth_date  \
# 0            160    Individual  Jacobus Henricus van 't Hoff  1852-08-30
# 1            569    Individual               Sully Prudhomme  1839-03-16
# 2            293    Individual        Emil Adolf von Behring  1854-03-15
# 3            462    Individual             Jean Henry Dunant  1828-05-08
# 4            463    Individual                Frédéric Passy  1822-05-20
# ..           ...           ...                           ...         ...
# 906          927    Individual              Yoshinori Ohsumi  1945-02-09
# 907          934    Individual            Juan Manuel Santos  1951-08-10
# 908          928    Individual             David J. Thouless  1934-09-21
# 909          929    Individual          F. Duncan M. Haldane  1951-09-14
# 910          930    Individual         J. Michael Kosterlitz  1943-06-22
#
#             birth_city     birth_country   sex              organization_name  \
# 0            Rotterdam       Netherlands  Male              Berlin University
# 1                Paris            France  Male                            NaN
# 2    Hansdorf (Lawice)  Prussia (Poland)  Male             Marburg University
# 3               Geneva       Switzerland  Male                            NaN
# 4                Paris            France  Male                            NaN
# ..                 ...               ...   ...                            ...
# 906            Fukuoka             Japan  Male  Tokyo Institute of Technology
# 907             Bogotá          Colombia  Male                            NaN
# 908           Bearsden    United Kingdom  Male       University of Washington
# 909             London    United Kingdom  Male           Princeton University
# 910           Aberdeen    United Kingdom  Male               Brown University
#
#     organization_city      organization_country  death_date death_city  \
# 0              Berlin                   Germany  1911-03-01     Berlin
# 1                 NaN                       NaN  1907-09-07   Châtenay
# 2             Marburg                   Germany  1917-03-31    Marburg
# 3                 NaN                       NaN  1910-10-30     Heiden
# 4                 NaN                       NaN  1912-06-12      Paris
# ..                ...                       ...         ...        ...
# 906             Tokyo                     Japan         NaN        NaN
# 907               NaN                       NaN         NaN        NaN
# 908       Seattle, WA  United States of America         NaN        NaN
# 909     Princeton, NJ  United States of America         NaN        NaN
# 910    Providence, RI  United States of America         NaN        NaN
#
#     death_country
# 0         Germany
# 1          France
# 2         Germany
# 3     Switzerland
# 4          France
# ..            ...
# 906           NaN
# 907           NaN
# 908           NaN
# 909           NaN
# 910           NaN
#
# [911 rows x 18 columns]>

# %% [markdown]
# # 1c)
#
# Show the first 5 listings of the dataset.

# %%
df.head(5)
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   laureate_type                     full_name  birth_date         birth_city  \
# 0    Individual  Jacobus Henricus van 't Hoff  1852-08-30          Rotterdam
# 1    Individual               Sully Prudhomme  1839-03-16              Paris
# 2    Individual        Emil Adolf von Behring  1854-03-15  Hansdorf (Lawice)
# 3    Individual             Jean Henry Dunant  1828-05-08             Geneva
# 4    Individual                Frédéric Passy  1822-05-20              Paris
#
#       birth_country   sex   organization_name organization_city  \
# 0       Netherlands  Male   Berlin University            Berlin
# 1            France  Male                 NaN               NaN
# 2  Prussia (Poland)  Male  Marburg University           Marburg
# 3       Switzerland  Male                 NaN               NaN
# 4            France  Male                 NaN               NaN
#
#   organization_country  death_date death_city death_country
# 0              Germany  1911-03-01     Berlin       Germany
# 1                  NaN  1907-09-07   Châtenay        France
# 2              Germany  1917-03-31    Marburg       Germany
# 3                  NaN  1910-10-30     Heiden   Switzerland
# 4                  NaN  1912-06-12      Paris        France

# %% [markdown]
# # Problem 2
#
# How many null ('NaN') values there are in each *catagory*? What is the total number of Null values in the DataFrame?

# %%
print(df.isna().sum())
# Out:
# year                      0
# category                  0
# prize                     0
# motivation               88
# prize_share               0
# laureate_id               0
# laureate_type             0
# full_name                 0
# birth_date               28
# birth_city               28
# birth_country            26
# sex                      26
# organization_name       246
# organization_city       244
# organization_country    244
# death_date              318
# death_city              335
# death_country           329
# dtype: int64

# %%
print("total: ")
print(df.isna().sum().sum())
# Out:
# total:
# 1912

# %% [markdown]
# # Problem 3
#
# Make a histogram of the number of nobel prizes awarded per year. Around which decade (1900, 1910, 1920, ...) were the least amount of prizes awarded?

# %%
axis = df.year.hist()
#around the 1920's the least amount of prizes were awarded.
# Out:
# <img src="data:image/png;base64,..." width="639.65">

# %% [markdown]
# # Problem 4
#
# Use groupby method to printout the number of prizes awarded to each category. Which categroy has the most prizes?

# %%
category_num = df.groupby('category').size()
cat_num_sort = category_num.sort_values()
print(cat_num_sort)
# Out:
# category
# Economics      78
# Literature    113
# Peace         130
# Chemistry     175
# Physics       204
# Medicine      211
# dtype: int64

# %%
#the medicine category has the most prizes.

# %% [markdown]
# # Problem 5
#
# Find percentage of the prizes were awarded to 1, 2, 3, and 4 people? Meaning what percentage of 1/1, 1/2, 1/3, and 1/4 prize_shares are there?

# %%
prize_shares = df['prize_share'].value_counts()
total_prize = len(df)

percent_prizes = (prize_shares/ total_prize) * 100
print(percent_prizes)
# Out:
# 1/1    37.760703
# 1/2    33.589462
# 1/3    22.063666
# 1/4     6.586169
# Name: prize_share, dtype: float64

# %% [markdown]
# # Problem 6
#
# Determine how many males and females won the prize. Does the sum of male and female prizes add up to the total entries? If not, why?
#
# On the same graph make histograms for the numbber of males and females that won the prize each year.

# %%
num_genders = df['sex'].value_counts()
print(num_genders)
print(len(df))
#not it does not add up, some of the entries for sex are mising

g_counts = df.groupby(['year', 'sex']).size().unstack(fill_value = 0)
fig, ax = plt.subplots()

males = amnt_year['Male']
females = amnt_year['Female']
years = g_counts.index

ax.bar(years, males, label = 'Male')
ax.bar(years,females, label = 'Female')
ax.set_xlabel('Year')
ax.set_ylabel('# of recipients')
ax.set_title('Recipients by gender')
ax.legend()
# Out:
# Male      836
# Female     49
# Name: sex, dtype: int64
# 911
# <img src="data:image/png;base64,..." width="640.2">

# %% [markdown]
# # Problem 7
#
# How many prizes were won by those whose birth country was United States of America?

# %%
us_birthAmnt = len(df[df['birth_country'] == 'United States of America'])
print("Amount of prizes:", us_birthAmnt)
# Out:
# Amount of prizes: 259

# %% [markdown]
# # Problem 8
#
# Determine the age that each of the prize winners was when they won the prize. Find the youngest and oldest to win the prize. Find the mean age to win the prize, and the standard deviation of it. Make a histogram of the age each person was when they won the prize.
#
# ### Hint: You can use Pandas DatetimeIndex method to extract the year from the date format yyyy-mm-dd
# > pd.DatetimeIndex(date).year
#
# Where *date* is given in a formate like year-month-day, the above will returen the year, hence the *.year* in the call above. Use 'shit+tab' on pandas.DatetimeIndex to learn more.

# %%
#something wrong with calculatino, giving me wrong person and ages?

df['birth_date'] = pd.to_datetime(df['birth_date'])
df['year'] = pd.to_datetime(df['year'], format = '%Y')
df['age'] = (df['year'] - df['birth_date']).dt.days // 365

youngest_winner = df[df['age'] == df['age'].min()]
oldest_winner = df[df['age'] == df['age'].max()]

mean_age = df['age'].mean()
std_dev = df['age'].std()

print('Youngest winner:', youngest_winner[['full_name', 'age']])
print('Oldest winner: ', oldest_winner[['full_name', 'age']])
print('Mean age:', mean_age)
print('std deviation:', std_dev)

plt.figure()
plt.hist(df['age'], bins=20)
plt.xlabel('Age')
plt.ylabel('# of winners')
# Out:
# Youngest winner:             full_name   age
# 885  Malala Yousafzai -28.0
# Oldest winner:                              full_name    age
# 7  Christian Matthias Theodor Mommsen  152.0
# Mean age: 59.48697621744054
# std deviation: 31.263756160071306
# <img src="data:image/png;base64,..." width="640.2">
# Text(0, 0.5, '# of winners')

# %% [markdown]
# # Problem 9
#
# Make a copy of the current DataFrame. Then drop the column *lauret_id* from the copied DataFrame (do this inplace so this column is gone).

# %%
df_new = df.copy()
df_new.drop(columns=['laureate_id'], inplace=True)
df_new
# Out:
#                              year    category  \
# 0   1970-01-01 00:00:00.000001901   Chemistry
# 1   1970-01-01 00:00:00.000001901  Literature
# 2   1970-01-01 00:00:00.000001901    Medicine
# 3   1970-01-01 00:00:00.000001901       Peace
# 4   1970-01-01 00:00:00.000001901       Peace
# ..                            ...         ...
# 906 1970-01-01 00:00:00.000002016    Medicine
# 907 1970-01-01 00:00:00.000002016       Peace
# 908 1970-01-01 00:00:00.000002016     Physics
# 909 1970-01-01 00:00:00.000002016     Physics
# 910 1970-01-01 00:00:00.000002016     Physics
#
#                                               prize  \
# 0                 The Nobel Prize in Chemistry 1901
# 1                The Nobel Prize in Literature 1901
# 2    The Nobel Prize in Physiology or Medicine 1901
# 3                        The Nobel Peace Prize 1901
# 4                        The Nobel Peace Prize 1901
# ..                                              ...
# 906  The Nobel Prize in Physiology or Medicine 2016
# 907                      The Nobel Peace Prize 2016
# 908                 The Nobel Prize in Physics 2016
# 909                 The Nobel Prize in Physics 2016
# 910                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# 0    "in recognition of the extraordinary services ...         1/1
# 1    "in special recognition of his poetic composit...         1/1
# 2    "for his work on serum therapy, especially its...         1/1
# 3                                                  NaN         1/2
# 4                                                  NaN         1/2
# ..                                                 ...         ...
# 906  "for his discoveries of mechanisms for autophagy"         1/1
# 907  "for his resolute efforts to bring the country...         1/1
# 908  "for theoretical discoveries of topological ph...         1/2
# 909  "for theoretical discoveries of topological ph...         1/4
# 910  "for theoretical discoveries of topological ph...         1/4
#
#     laureate_type                     full_name birth_date         birth_city  \
# 0      Individual  Jacobus Henricus van 't Hoff 1852-08-30          Rotterdam
# 1      Individual               Sully Prudhomme 1839-03-16              Paris
# 2      Individual        Emil Adolf von Behring 1854-03-15  Hansdorf (Lawice)
# 3      Individual             Jean Henry Dunant 1828-05-08             Geneva
# 4      Individual                Frédéric Passy 1822-05-20              Paris
# ..            ...                           ...        ...                ...
# 906    Individual              Yoshinori Ohsumi 1945-02-09            Fukuoka
# 907    Individual            Juan Manuel Santos 1951-08-10             Bogotá
# 908    Individual             David J. Thouless 1934-09-21           Bearsden
# 909    Individual          F. Duncan M. Haldane 1951-09-14             London
# 910    Individual         J. Michael Kosterlitz 1943-06-22           Aberdeen
#
#         birth_country   sex              organization_name organization_city  \
# 0         Netherlands  Male              Berlin University            Berlin
# 1              France  Male                            NaN               NaN
# 2    Prussia (Poland)  Male             Marburg University           Marburg
# 3         Switzerland  Male                            NaN               NaN
# 4              France  Male                            NaN               NaN
# ..                ...   ...                            ...               ...
# 906             Japan  Male  Tokyo Institute of Technology             Tokyo
# 907          Colombia  Male                            NaN               NaN
# 908    United Kingdom  Male       University of Washington       Seattle, WA
# 909    United Kingdom  Male           Princeton University     Princeton, NJ
# 910    United Kingdom  Male               Brown University    Providence, RI
#
#          organization_country  death_date death_city death_country    age
# 0                     Germany  1911-03-01     Berlin       Germany  117.0
# 1                         NaN  1907-09-07   Châtenay        France  130.0
# 2                     Germany  1917-03-31    Marburg       Germany  115.0
# 3                         NaN  1910-10-30     Heiden   Switzerland  141.0
# 4                         NaN  1912-06-12      Paris        France  147.0
# ..                        ...         ...        ...           ...    ...
# 906                     Japan         NaN        NaN           NaN   24.0
# 907                       NaN         NaN        NaN           NaN   18.0
# 908  United States of America         NaN        NaN           NaN   35.0
# 909  United States of America         NaN        NaN           NaN   18.0
# 910  United States of America         NaN        NaN           NaN   26.0
#
# [911 rows x 18 columns]

# %% [markdown]
# # Problem 10
#
# Add the age column you calculated in Problem 8 to the DataFrame.

# %%
df_new['Age'] = (df['age'])
df_new
# Out:
#                              year    category  \
# 0   1970-01-01 00:00:00.000001901   Chemistry
# 1   1970-01-01 00:00:00.000001901  Literature
# 2   1970-01-01 00:00:00.000001901    Medicine
# 3   1970-01-01 00:00:00.000001901       Peace
# 4   1970-01-01 00:00:00.000001901       Peace
# ..                            ...         ...
# 906 1970-01-01 00:00:00.000002016    Medicine
# 907 1970-01-01 00:00:00.000002016       Peace
# 908 1970-01-01 00:00:00.000002016     Physics
# 909 1970-01-01 00:00:00.000002016     Physics
# 910 1970-01-01 00:00:00.000002016     Physics
#
#                                               prize  \
# 0                 The Nobel Prize in Chemistry 1901
# 1                The Nobel Prize in Literature 1901
# 2    The Nobel Prize in Physiology or Medicine 1901
# 3                        The Nobel Peace Prize 1901
# 4                        The Nobel Peace Prize 1901
# ..                                              ...
# 906  The Nobel Prize in Physiology or Medicine 2016
# 907                      The Nobel Peace Prize 2016
# 908                 The Nobel Prize in Physics 2016
# 909                 The Nobel Prize in Physics 2016
# 910                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# 0    "in recognition of the extraordinary services ...         1/1
# 1    "in special recognition of his poetic composit...         1/1
# 2    "for his work on serum therapy, especially its...         1/1
# 3                                                  NaN         1/2
# 4                                                  NaN         1/2
# ..                                                 ...         ...
# 906  "for his discoveries of mechanisms for autophagy"         1/1
# 907  "for his resolute efforts to bring the country...         1/1
# 908  "for theoretical discoveries of topological ph...         1/2
# 909  "for theoretical discoveries of topological ph...         1/4
# 910  "for theoretical discoveries of topological ph...         1/4
#
#     laureate_type                     full_name birth_date         birth_city  \
# 0      Individual  Jacobus Henricus van 't Hoff 1852-08-30          Rotterdam
# 1      Individual               Sully Prudhomme 1839-03-16              Paris
# 2      Individual        Emil Adolf von Behring 1854-03-15  Hansdorf (Lawice)
# 3      Individual             Jean Henry Dunant 1828-05-08             Geneva
# 4      Individual                Frédéric Passy 1822-05-20              Paris
# ..            ...                           ...        ...                ...
# 906    Individual              Yoshinori Ohsumi 1945-02-09            Fukuoka
# 907    Individual            Juan Manuel Santos 1951-08-10             Bogotá
# 908    Individual             David J. Thouless 1934-09-21           Bearsden
# 909    Individual          F. Duncan M. Haldane 1951-09-14             London
# 910    Individual         J. Michael Kosterlitz 1943-06-22           Aberdeen
#
#         birth_country   sex              organization_name organization_city  \
# 0         Netherlands  Male              Berlin University            Berlin
# 1              France  Male                            NaN               NaN
# 2    Prussia (Poland)  Male             Marburg University           Marburg
# 3         Switzerland  Male                            NaN               NaN
# 4              France  Male                            NaN               NaN
# ..                ...   ...                            ...               ...
# 906             Japan  Male  Tokyo Institute of Technology             Tokyo
# 907          Colombia  Male                            NaN               NaN
# 908    United Kingdom  Male       University of Washington       Seattle, WA
# 909    United Kingdom  Male           Princeton University     Princeton, NJ
# 910    United Kingdom  Male               Brown University    Providence, RI
#
#          organization_country  death_date death_city death_country    age  \
# 0                     Germany  1911-03-01     Berlin       Germany  117.0
# 1                         NaN  1907-09-07   Châtenay        France  130.0
# 2                     Germany  1917-03-31    Marburg       Germany  115.0
# 3                         NaN  1910-10-30     Heiden   Switzerland  141.0
# 4                         NaN  1912-06-12      Paris        France  147.0
# ..                        ...         ...        ...           ...    ...
# 906                     Japan         NaN        NaN           NaN   24.0
# 907                       NaN         NaN        NaN           NaN   18.0
# 908  United States of America         NaN        NaN           NaN   35.0
# 909  United States of America         NaN        NaN           NaN   18.0
# 910  United States of America         NaN        NaN           NaN   26.0
#
#        Age
# 0    117.0
# 1    130.0
# 2    115.0
# 3    141.0
# 4    147.0
# ..     ...
# 906   24.0
# 907   18.0
# 908   35.0
# 909   18.0
# 910   26.0
#
# [911 rows x 19 columns]
